# %% [markdown]
# <a href="https://colab.research.google.com/github/vidhya2324/Machine_learning/blob/main/Fingerprint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras import layers
from keras.models import Model
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from imgaug import augmenters as iaa

import random

# %%
pip install numpy==1.15.4
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 12.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for numpy
#   Running setup.py clean for numpy
#   error: subprocess-exited-with-error
#
#   × python setup.py clean did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed cleaning build dir for numpy
# Failed to build numpy
# ERROR: Could not build wheels for numpy, which is required to install pyproject.toml-based projects

# %% [markdown]
# #load dataset

# %%
import numpy as np

# Try to load the file without `allow_pickle=True`
try:
    data = np.load('/content/x_hard.npz')
    print(data.files)  # Print the list of arrays in the file
    # Access and print individual arrays to check contents
    for key in data.files:
        print(key, data[key].shape)  # Print shape of each array
except Exception as e:
    print(f"Error loading file: {e}")
# Out:
# Error loading file: Cannot load file containing pickled data when allow_pickle=False

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load data with allow_pickle=True explicitly set
x_real = np.load('/content/x_real.npz', allow_pickle=True)['data']
y_real = np.load('/content/y_easy.npy', allow_pickle=True)
x_easy = np.load('/content/x_easy.npz', allow_pickle=True)['data']
y_easy = np.load('/content/y_easy.npy', allow_pickle=True)
x_medium = np.load('/content/x_medium.npz', allow_pickle=True)['data']
y_medium = np.load('/content/y_medium.npy', allow_pickle=True)
#x_hard = np.load('/content/x_hard.npz', allow_pickle=True)['data']
y_hard = np.load('/content/y_hard.npy', allow_pickle=True)

# Check shapes to verify data loaded correctly
print(x_real.shape, y_real.shape)
print(x_easy.shape, y_easy.shape)
print(x_medium.shape, y_medium.shape)
#print(x_hard.shape, y_hard.shape)

# Plot example images to verify
plt.figure(figsize=(15, 10))
plt.subplot(1, 4, 1)
# Convert the array to a string representation for the title
plt.title(str(y_real[0]))
plt.imshow(x_real[0].squeeze(), cmap='gray')
plt.subplot(1, 4, 2)
plt.title(str(y_easy[0]))  # Convert array to string
plt.imshow(x_easy[0].squeeze(), cmap='gray')
plt.subplot(1, 4, 3)
plt.title(str(y_medium[0]))  # Convert array to string
plt.imshow(x_medium[0].squeeze(), cmap='gray')
plt.subplot(1, 4, 4)
plt.title(str(y_hard[0]))  # Convert array to string
#plt.imshow(x_hard[0].squeeze(), cmap='gray')
plt.show()
# Out:
# (6000, 90, 90, 1) (17931, 4)
# (17931, 90, 90, 1) (17931, 4)
# (17067, 90, 90, 1) (17067, 4)
