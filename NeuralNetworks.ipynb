# %% [markdown]
# <a href="https://colab.research.google.com/github/vidhya2324/Machine_learning/blob/main/NeuralNetworks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/pima-indians-diabetes.csv")

# %%
df.shape
# Out:
# (768, 9)

# %%
df.tail()
# Out:
#      Preg  Plas  Pres  skin  test  mass   pedi  age  class
# 763    10   101    76    48   180  32.9  0.171   63      0
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0

# %%
X = df.drop("class",axis=1)

# %%
X.head()
# Out:
#    Preg  Plas  Pres  skin  test  mass   pedi  age
# 0     6   148    72    35     0  33.6  0.627   50
# 1     1    85    66    29     0  26.6  0.351   31
# 2     8   183    64     0     0  23.3  0.672   32
# 3     1    89    66    23    94  28.1  0.167   21
# 4     0   137    40    35   168  43.1  2.288   33

# %%
y= df['class']

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: class, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=45)

# %%
X_train.shape
# Out:
# (614, 8)

# %%
X_test.shape
# Out:
# (154, 8)

# %% [markdown]
# #pima indian dataset

# %%
# create model
model = Sequential()
model.add(Dense(12, input_dim=8,  activation='relu'))
model.add(Dense(10, activation='relu'))
#model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 12)                108
#
#  dense_1 (Dense)             (None, 10)                130
#
#  dense_2 (Dense)             (None, 10)                110
#
#  dense_3 (Dense)             (None, 1)                 11
#
# ...
# Total params: 359 (1.40 KB)
# Trainable params: 359 (1.40 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Fit the model
model.fit(X_train,y_train, epochs=400, batch_size=80)
# Out:
# Epoch 1/400
# 8/8 [==============================] - 3s 5ms/step - loss: 9.6470 - accuracy: 0.6450
# Epoch 2/400
# 8/8 [==============================] - 0s 4ms/step - loss: 6.6488 - accuracy: 0.6450
# Epoch 3/400
# 8/8 [==============================] - 0s 4ms/step - loss: 4.3479 - accuracy: 0.6450
# Epoch 4/400
# 8/8 [==============================] - 0s 4ms/step - loss: 2.7709 - accuracy: 0.6450
# Epoch 5/400
# 8/8 [==============================] - 0s 4ms/step - loss: 1.8580 - accuracy: 0.6450
# Epoch 6/400
# 8/8 [==============================] - 0s 4ms/step - loss: 1.5132 - accuracy: 0.6450
# Epoch 7/400
# 8/8 [==============================] - 0s 4ms/step - loss: 1.3207 - accuracy: 0.6450
# Epoch 8/400
# 8/8 [==============================] - 0s 4ms/step - loss: 1.1823 - accuracy: 0.6450
# Epoch 9/400
# 8/8 [==============================] - 0s 4ms/step - loss: 1.0689 - accuracy: 0.6450
# Epoch 10/400
# ...

# %%
# evaluate the model
scores = model.evaluate(X_test, y_test)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6113 - accuracy: 0.7013
# accuracy: 70.13%
